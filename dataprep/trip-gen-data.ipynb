# %%
import pandas as pd

#google cloud big query libaries
from google.cloud import bigquery
from google.oauth2 import service_account

import os

# %%
dirShiny = "E:/GitHub/Resources/R-Shiny/HTS-Trip-Lengths/input"

group_by_columns = ['groupSampleSegment','groupNumWorkers','groupNumVehicles','groupTripType','groupModeTypeBroad']
display(group_by_columns)
# Out:
# ['groupSampleSegment',
#  'groupNumWorkers',
#  'groupNumVehicles',
#  'groupTripType',
#  'groupModeTypeBroad']

# %% [markdown]
# # Setup Data

# %%
# Link to BigQuery Client through API

key_path = r"C:\Users\bhereth\confidential-2023-utah-hts-db5335615978.json"
#key_path = r"C:\Users\bhereth\tdm-scenarios-a85044dbbfd3.json"

credentials = service_account.Credentials.from_service_account_file(
    key_path, scopes=["https://www.googleapis.com/auth/cloud-platform"],
)

client = bigquery.Client(credentials=credentials, project=credentials.project_id,)
print ('Successfully Linked to BigQuery Client!')
# Out:
# Successfully Linked to BigQuery Client!

# %%
str_sql_trips = """
SELECT
  gSs.groupSampleSegment,
  gNw.groupNumWorkers,
  gNv.groupNumVehicles,
  gMtb.groupModeTypeBroad,
  trip.trip_type AS trip_type,
  COUNT(*) as numTripRecords,
  ROUND(SUM(trip.trip_weight),2) AS sumTripWeight
FROM
  `confidential-2023-utah-hts.20230313.hh` as hh,
  `confidential-2023-utah-hts.20230313.trip` as trip,
  `confidential-2023-utah-hts.20230313_groupings.groupSampleSegment` as gSs,
  `confidential-2023-utah-hts.20230313_groupings.groupNumWorkers` as gNw,
  `confidential-2023-utah-hts.20230313_groupings.groupNumVehicles` as gNv,
  `confidential-2023-utah-hts.20230313_groupings.groupModeTypeBroad` as gMtb
WHERE
  hh.sample_segment = gSs.sample_segment AND
  hh.hh_id = trip.hh_id AND
  hh.num_workers = gNw.num_workers AND
  hh.num_vehicles = gNv.num_vehicles AND
  trip.mode_type_broad = gMtb.mode_type_broad
GROUP BY
  gSs.groupSampleSegment,
  gNw.groupNumWorkers,
  gNv.groupNumVehicles,
  gMtb.groupModeTypeBroad,
  trip.trip_type
"""

# %%
str_sql_hh = """
SELECT
  gSs.groupSampleSegment,
  gNw.groupNumWorkers,
  gNv.groupNumVehicles,
  COUNT(*) as numHhRecords,
  ROUND(SUM(hh.hh_weight),2) AS sumHhWeight
FROM
  `confidential-2023-utah-hts.20230313.hh` as hh,
  `confidential-2023-utah-hts.20230313_groupings.groupSampleSegment` as gSs,
  `confidential-2023-utah-hts.20230313_groupings.groupNumWorkers` as gNw,
  `confidential-2023-utah-hts.20230313_groupings.groupNumVehicles` as gNv
WHERE
  hh.sample_segment = gSs.sample_segment AND
  hh.num_workers = gNw.num_workers AND
  hh.num_vehicles = gNv.num_vehicles
GROUP BY
  gSs.groupSampleSegment,
  gNw.groupNumWorkers,
  gNv.groupNumVehicles
"""

# %%
# test connection
df_trips_by_type = client.query(str_sql_trips).to_dataframe()

display(df_trips_by_type)
# Out:
#       groupSampleSegment  groupNumWorkers  groupNumVehicles  \
# 0                     WF               -1                 3
# 1                     WF               -1                 3
# 2                     WF               -1                -1
# 3                     WF               -1                -1
# 4                     WF                3                 3
# ...                  ...              ...               ...
# 24676                 Bo                3                 6
# 24677                 Un                4                 1
# 24678                 WF                3                 6
# 24679                 Sa                3                 6
# 24680                 Un                4                 5
#
#        groupModeTypeBroad  trip_type  numTripRecords  sumTripWeight
# 0                       5          6             108        4703.52
# 1                      -1          6            3146      220844.47
# 2                       5          6             466       19814.33
# 3                      -1          6           19590      925526.43
# 4                       5          6              75         977.76
# ...                   ...        ...             ...            ...
# 24676                 995        995               2          16.76
# 24677                 995        995               3          14.51
# 24678                 995        995               2        1263.43
# 24679                 995        995               2        1263.43
# 24680                 995        995               6         205.70
#
# [24681 rows x 7 columns]

# %%
df_trips_by_type[df_trips_by_type['trip_type']==995]
# Out:
#       groupSampleSegment  groupNumWorkers  groupNumVehicles  \
# 24                    WF               -1                 5
# 25                    WF               -1                 5
# 26                    WF               -1                -1
# 27                    WF               -1                -1
# 28                    WF                3                 5
# ...                  ...              ...               ...
# 24676                 Bo                3                 6
# 24677                 Un                4                 1
# 24678                 WF                3                 6
# 24679                 Sa                3                 6
# 24680                 Un                4                 5
#
#        groupModeTypeBroad  trip_type  numTripRecords  sumTripWeight
# 24                      5        995              13         820.84
# 25                     -1        995            1006       51159.65
# 26                      5        995             710       37972.51
# 27                     -1        995           57659     1941406.20
# 28                      5        995               2          96.11
# ...                   ...        ...             ...            ...
# 24676                 995        995               2          16.76
# 24677                 995        995               3          14.51
# 24678                 995        995               2        1263.43
# 24679                 995        995               2        1263.43
# 24680                 995        995               6         205.70
#
# [4058 rows x 7 columns]

# %%
# test connection
df_hh = client.query(str_sql_hh).to_dataframe()

display(df_hh)
# Out:
#     groupSampleSegment  groupNumWorkers  groupNumVehicles  numHhRecords  \
# 0                   TT               -1                -1         11183
# 1                   TT               -1                 4           491
# 2                   TT                2                -1          3601
# 3                   TT                2                 4           149
# 4                   Bo               -1                -1           449
# ..                 ...              ...               ...           ...
# 763                 Su                3                 0             1
# 764                 TT                7                 4             1
# 765                 Su                7                -1             1
# 766                 Su                7                 4             1
# 767                 Su                0                 3             1
#
#      sumHhWeight
# 0     1137207.98
# 1       70403.31
# 2      338730.63
# 3       22666.22
# 4       46262.44
# ..           ...
# 763        14.98
# 764        16.25
# 765        16.25
# 766        16.25
# 767        16.40
#
# [768 rows x 5 columns]

# %%
df_trips_by_type_hh = pd.merge(df_trips_by_type, df_hh, on=[col for col in group_by_columns if col not in ['groupTripType', 'groupModeTypeBroad']])
df_trips_by_type_hh['tripsPerHh'] = df_trips_by_type_hh['sumTripWeight'] / df_trips_by_type_hh['sumHhWeight'] 
df_trips_by_type_hh['tripsPerHh'].fillna(0, inplace=True)
df_trips_by_type_hh
# Out:
#       groupSampleSegment  groupNumWorkers  groupNumVehicles  \
# 0                     WF               -1                 3
# 1                     WF               -1                 3
# 2                     WF               -1                 3
# 3                     WF               -1                 3
# 4                     WF               -1                 3
# ...                  ...              ...               ...
# 24676                 Al                3                 1
# 24677                 Al                3                 1
# 24678                 Al                3                 1
# 24679                 Al                3                 1
# 24680                 Al                3                 1
#
#        groupModeTypeBroad  trip_type  numTripRecords  sumTripWeight  \
# 0                       5          6             108        4703.52
# 1                      -1          6            3146      220844.47
# 2                       1          7             790       32005.84
# 3                      -1          7            9751      361858.61
# 4                    1001          7             883       32469.49
# ...                   ...        ...             ...            ...
# 24676                   3          2               1          59.59
# 24677                  -1          2               1          59.59
# 24678                   3          7               1          36.31
# 24679                  -1          7               1          36.31
# 24680                 995        995               3         119.50
#
#        numHhRecords  sumHhWeight  tripsPerHh
# 0               906    139950.11    0.033609
# 1               906    139950.11    1.578023
# 2               906    139950.11    0.228695
# 3               906    139950.11    2.585626
# 4               906    139950.11    0.232008
# ...             ...          ...         ...
# 24676             1        36.31    1.641146
# 24677             1        36.31    1.641146
# 24678             1        36.31    1.000000
# 24679             1        36.31    1.000000
# 24680             1        36.31    3.291104
#
# [24681 rows x 10 columns]

# %%
df_trip_types = client.query("SELECT * FROM confidential-2023-utah-hts.20230313.value_labels WHERE table='trip' AND variable='trip_type'").to_dataframe()
df_trip_types.drop(columns=['table','variable'], inplace=True)
df_trip_types.rename(columns={'value':'trip_type','label':'tripTypeLabel'}, inplace=True)
df_trip_types['tripTypeLabel'] = df_trip_types['tripTypeLabel'].apply(lambda x: '\n'.join(x.split()))
df_trip_types['tripTypeLabel'] = df_trip_types['tripTypeLabel'].apply(lambda x: '-\n'.join(x.split('-')))
df_trip_types['trip_type'] = df_trip_types['trip_type'].astype(int)
df_trip_types
# Out:
#    trip_type                     tripTypeLabel
# 0          4  Home-\nbased\npersonal\nbusiness
# 1          2              Home-\nbased\nschool
# 2          6          Non-\nhome-\nbased\nwork
# 3          7    Non-\nhome-\nbased\nnon-\nwork
# 4          1                Home-\nbased\nwork
# 5          3            Home-\nbased\nshopping
# 6          5               Home-\nbased\nother
# 7        995                 Missing\nresponse

# %%
df_trips_by_type_hh_with_labels = pd.merge(df_trips_by_type_hh, df_trip_types, on='trip_type')
df_trips_by_type_hh_with_labels
# Out:
#       groupSampleSegment  groupNumWorkers  groupNumVehicles  \
# 0                     WF               -1                 3
# 1                     WF               -1                 3
# 2                     WF               -1                 3
# 3                     WF               -1                 3
# 4                     WF               -1                 3
# ...                  ...              ...               ...
# 24676                 Ir                4                 5
# 24677                 Ir                3                 5
# 24678                 Ir                3                 5
# 24679                 Ir                1                 5
# 24680                 Ir                1                 5
#
#        groupModeTypeBroad  trip_type  numTripRecords  sumTripWeight  \
# 0                       5          6             108        4703.52
# 1                      -1          6            3146      220844.47
# 2                       1          6             237       14026.42
# 3                    1001          6             289       16058.73
# 4                       3          6            2579      195394.25
# ...                   ...        ...             ...            ...
# 24676                  -1          1               2          34.68
# 24677                   3          1               1          93.07
# 24678                  -1          1               1          93.07
# 24679                   3          1               1          16.80
# 24680                  -1          1               1          16.80
#
#        numHhRecords  sumHhWeight  tripsPerHh             tripTypeLabel
# 0               906    139950.11    0.033609  Non-\nhome-\nbased\nwork
# 1               906    139950.11    1.578023  Non-\nhome-\nbased\nwork
# 2               906    139950.11    0.100224  Non-\nhome-\nbased\nwork
# 3               906    139950.11    0.114746  Non-\nhome-\nbased\nwork
# 4               906    139950.11    1.396171  Non-\nhome-\nbased\nwork
# ...             ...          ...         ...                       ...
# 24676             1        10.57    3.280984        Home-\nbased\nwork
# 24677             1        56.71    1.641157        Home-\nbased\nwork
# 24678             1        56.71    1.641157        Home-\nbased\nwork
# 24679             1        10.24    1.640625        Home-\nbased\nwork
# 24680             1        10.24    1.640625        Home-\nbased\nwork
#
# [24681 rows x 11 columns]

# %%
df_trips_by_type_hh_with_labels.to_csv('trips_by_type.csv', index=False)
